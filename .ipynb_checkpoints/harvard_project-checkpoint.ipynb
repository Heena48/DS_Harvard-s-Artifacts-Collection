# %%
import requests 
import pandas as pd#importing request package
API_KEY = "69d609a4-770b-4c37-926f-86919d2bdbf4"  #---api from the harvard
url = "https://api.harvardartmuseums.org/classification" #classification url
para = {
    "apikey":API_KEY,
    "size":100
} #--getting the 1st 100 value from the record

response = requests.get(url,para)   #requesting the url with given parameters
response #calling
# Out:
# <Response [200]>

# %%
data = response.json()  #assigning data in json format

# %%
data.keys()
# Out:
# dict_keys(['info', 'records'])

# %%
data_records = data['records']

# %%
##for record in data_records:
##    print(data_records)
   
object_count_above_2500 = 2500 #setting the mininum value for the record
object_count= []  #assigning it to the empty list 

for record in data['records']:  #iterating the records 
    if record.get('objectcount', 0) >= object_count_above_2500:  #this condition checks each and every recored and check the condition
        object_count.append(record.get('name', 'Unknown')) # if the condition satisfys it gets the name of that records if there is none it returns unkonwn

print("Collections with greater than 2500 objects:",object_count)
# Out:
# Collections with greater than 2500 objects: ['Accessories (non-art)', 'Photographs', 'Drawings', 'Prints', 'Paintings', 'Sculpture', 'Coins', 'Vessels', 'Textile Arts', 'Archival Material', 'Fragments', 'Manuscripts', 'Seals', 'Straus Materials']

# %%
url = "https://api.harvardartmuseums.org/object"
classfication_fetched =['Prints','Paintings','Fragments','Sculpture','Archival Material']
para = {"apikey": API_KEY,
    "size":100,
    "page":1,
    "classifcations":classfication_fetched}

response = requests.get(url,para)
data_objects = response.json()
data_objects
# Out:
# {'info': {'totalrecordsperquery': 100,
#   'totalrecords': 247767,
#   'pages': 2478,
#   'page': 1,
#   'next': 'https://api.harvardartmuseums.org/object?apikey=69d609a4-770b-4c37-926f-86919d2bdbf4&size=100&page=2&classifcations=Prints&classifcations=Paintings&classifcations=Fragments&classifcations=Sculpture&classifcations=Archival%20Material',
#   'responsetime': '45 ms'},
#  'records': [{'copyright': '© Artists Rights Society (ARS), New York / VG Bild-Kunst, Bonn',
#    'contextualtextcount': 0,
#    'creditline': 'Harvard Art Museums/Busch-Reisinger Museum, Gift of T. Lux Feininger',
#    'accesslevel': 1,
#    'createdate': '2006-01-20T00:00:00-05:00',
#    'dateoflastpageview': '2025-08-22',
#    'classificationid': 17,
#    'division': 'Modern and Contemporary Art',
#    'markscount': 0,
#    'publicationcount': 0,
#    'totaluniquepageviews': 75,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'colorcount': 3,
#    'rank': 196446,
#    'id': 1412,
#    'state': None,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'period': None,
#    'images': [],
#    'worktypes': [{'worktypeid': '341', 'worktype': 'slide'},
#     {'worktypeid': '268', 'worktype': 'photograph'}],
#    'imagecount': 1,
#    'totalpageviews': 162,
#    'accessionyear': None,
#    'standardreferencenumber': None,
#    'signed': None,
#    'classification': 'Photographs',
#    'relatedcount': 1,
#    'verificationlevel': 2,
#    'primaryimageurl': None,
#    'titlescount': 1,
#    'peoplecount': 1,
#    'style': None,
#    'lastupdate': '2025-09-01T04:57:44-04:00',
#    'commentary': None,
#    'periodid': None,
#    'technique': 'Slide, 35 mm, black and white',
#    'edition': None,
#    'description': 'Corresponds to negative BRLF.457.10',
#    'medium': None,
#    'lendingpermissionlevel': 0,
#    'title': '[Buildings, Germany (Siemensstadt?)]',
#    'accessionmethod': 'Gift',
#    'colors': [{'color': '#000000',
#      'spectrum': '#1eb264',
#      'hue': 'Black',
#      'percent': 0.6587987987987988,
#      'css3': '#000000'},
#     {'color': '#191919',
#      'spectrum': '#1eb264',
#      'hue': 'Grey',
#      'percent': 0.18684684684684685,
#      'css3': '#000000'},
#     {'color': '#969696',
#      'spectrum': '#8761aa',
#      'hue': 'Grey',
#      'percent': 0.15435435435435435,
#      'css3': '#a9a9a9'}],
#    'provenance': None,
#    'groupcount': 2,
#    'dated': '1940s-1950s',
#    'department': 'Busch-Reisinger Museum',
#    'dateend': 1959,
#    'people': [{'role': 'Artist',
#      'birthplace': 'New York, NY',
#      'gender': 'male',
#      'displaydate': '1871 - 1956',
#      'prefix': None,
#      'culture': 'American',
#      'displayname': 'Lyonel Feininger',
#      'alphasort': 'Feininger, Lyonel',
#      'name': 'Lyonel Feininger',
#      'personid': 20002,
#      'deathplace': 'New York, NY',
#      'displayorder': 1}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/1412',
#    'dateoffirstpageview': '2009-05-12',
#    'century': '20th century',
#    'objectnumber': 'BRLF.1002.214',
#    'labeltext': None,
#    'datebegin': 1940,
#    'culture': 'American',
#    'exhibitioncount': 0,
#    'imagepermissionlevel': 1,
#    'mediacount': 0,
#    'objectid': 1412,
#    'techniqueid': 220,
#    'dimensions': '3 x 3.5 cm (1 3/16 x 1 3/8 in.)',
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/1412',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#   {'copyright': '© Artists Rights Society (ARS), New York / VG Bild-Kunst, Bonn',
#    'contextualtextcount': 0,
#    'creditline': 'Harvard Art Museums/Busch-Reisinger Museum, Gift of T. Lux Feininger',
#    'accesslevel': 1,
#    'createdate': '2006-01-20T00:00:00-05:00',
#    'dateoflastpageview': '2025-05-18',
#    'classificationid': 17,
#    'division': 'Modern and Contemporary Art',
#    'markscount': 0,
#    'publicationcount': 0,
#    'totaluniquepageviews': 31,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'colorcount': 8,
#    'rank': 196447,
#    'id': 1413,
#    'state': None,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'period': None,
#    'images': [],
#    'worktypes': [{'worktypeid': '341', 'worktype': 'slide'},
#     {'worktypeid': '268', 'worktype': 'photograph'}],
#    'imagecount': 1,
#    'totalpageviews': 70,
#    'accessionyear': None,
#    'standardreferencenumber': None,
#    'signed': None,
#    'classification': 'Photographs',
#    'relatedcount': 1,
#    'verificationlevel': 2,
#    'primaryimageurl': None,
#    'titlescount': 1,
#    'peoplecount': 1,
#    'style': None,
#    'lastupdate': '2025-09-01T04:57:44-04:00',
#    'commentary': None,
#    'periodid': None,
#    'technique': 'Slide, 35 mm, black and white',
#    'edition': None,
#    'description': 'Corresponds to negative BRLF.196.13',
#    'medium': None,
#    'lendingpermissionlevel': 0,
#    'title': '[Buildings, Stockholm, 1936]',
#    'accessionmethod': 'Gift',
#    'colors': [{'color': '#323232',
#      'spectrum': '#2eb45d',
#      'hue': 'Grey',
#      'percent': 0.20660493827160495,
#      'css3': '#2f4f4f'},
#     {'color': '#4b4b4b',
#      'spectrum': '#3db657',
#      'hue': 'Grey',
#      'percent': 0.17969135802469136,
#      'css3': '#2f4f4f'},
#     {'color': '#afafaf',
#      'spectrum': '#8c5fa8',
#      'hue': 'Grey',
#      'percent': 0.14703703703703705,
#      'css3': '#a9a9a9'},
#     {'color': '#000000',
#      'spectrum': '#1eb264',
#      'hue': 'Black',
#      'percent': 0.11549382716049383,
#      'css3': '#000000'},
#     {'color': '#191919',
#      'spectrum': '#1eb264',
#      'hue': 'Grey',
#      'percent': 0.11475308641975308,
#      'css3': '#000000'},
#     {'color': '#c8c8c8',
#      'spectrum': '#8c5fa8',
#      'hue': 'Grey',
#      'percent': 0.09358024691358025,
#      'css3': '#c0c0c0'},
#     {'color': '#646464',
#      'spectrum': '#7866ad',
#      'hue': 'Grey',
#      'percent': 0.08179012345679013,
#      'css3': '#696969'},
#     {'color': '#7d7d7d',
#      'spectrum': '#8362aa',
#      'hue': 'Grey',
#      'percent': 0.061049382716049386,
#      'css3': '#808080'}],
#    'provenance': None,
#    'groupcount': 2,
#    'dated': '1940s-1950s',
#    'department': 'Busch-Reisinger Museum',
#    'dateend': 1959,
#    'people': [{'role': 'Artist',
#      'birthplace': 'New York, NY',
#      'gender': 'male',
#      'displaydate': '1871 - 1956',
#      'prefix': None,
#      'culture': 'American',
#      'displayname': 'Lyonel Feininger',
#      'alphasort': 'Feininger, Lyonel',
#      'name': 'Lyonel Feininger',
#      'personid': 20002,
#      'deathplace': 'New York, NY',
#      'displayorder': 1}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/1413',
#    'dateoffirstpageview': '2009-07-06',
#    'century': '20th century',
#    'objectnumber': 'BRLF.1002.215',
#    'labeltext': None,
#    'datebegin': 1940,
#    'culture': 'American',
#    'exhibitioncount': 0,
#    'imagepermissionlevel': 1,
#    'mediacount': 0,
#    'objectid': 1413,
#    'techniqueid': 220,
#    'dimensions': '3 x 3.5 cm (1 3/16 x 1 3/8 in.)',
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/1413',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#   {'copyright': '© Artists Rights Society (ARS), New York / VG Bild-Kunst, Bonn',
#    'contextualtextcount': 0,
#    'creditline': 'Harvard Art Museums/Busch-Reisinger Museum, Gift of T. Lux Feininger',
#    'accesslevel': 1,
#    'createdate': '2006-01-20T00:00:00-05:00',
#    'dateoflastpageview': '2025-03-26',
#    'classificationid': 17,
#    'division': 'Modern and Contemporary Art',
#    'markscount': 0,
#    'publicationcount': 0,
#    'totaluniquepageviews': 64,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'colorcount': 7,
#    'rank': 196454,
#    'id': 1414,
#    'state': None,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'period': None,
#    'images': [],
#    'worktypes': [{'worktypeid': '341', 'worktype': 'slide'},
#     {'worktypeid': '268', 'worktype': 'photograph'}],
#    'imagecount': 1,
#    'totalpageviews': 113,
#    'accessionyear': None,
#    'standardreferencenumber': None,
#    'signed': None,
#    'classification': 'Photographs',
#    'relatedcount': 1,
#    'verificationlevel': 2,
#    'primaryimageurl': None,
#    'titlescount': 1,
#    'peoplecount': 1,
#    'style': None,
#    'lastupdate': '2025-09-01T04:57:44-04:00',
#    'commentary': None,
#    'periodid': None,
#    'technique': 'Slide, 35 mm, black and white',
#    'edition': None,
#    'description': 'Corresponds to negative BRLF.413.6',
#    'medium': None,
#    'lendingpermissionlevel': 0,
#    'title': '[Street scene, Berlin]',
#    'accessionmethod': 'Gift',
#    'colors': [{'color': '#000000',
#      'spectrum': '#1eb264',
#      'hue': 'Black',
#      'percent': 0.2083809523809524,
#      'css3': '#000000'},
#     {'color': '#afafaf',
#      'spectrum': '#8c5fa8',
#      'hue': 'Grey',
#      'percent': 0.18641269841269842,
#      'css3': '#a9a9a9'},
#     {'color': '#323232',
#      'spectrum': '#2eb45d',
#      'hue': 'Grey',
#      'percent': 0.17142857142857143,
#      'css3': '#2f4f4f'},
#     {'color': '#c8c8c8',
#      'spectrum': '#8c5fa8',
#      'hue': 'Grey',
#      'percent': 0.12692063492063493,
#      'css3': '#c0c0c0'},
#     {'color': '#191919',
#      'spectrum': '#1eb264',
#      'hue': 'Grey',
#      'percent': 0.12266666666666666,
#      'css3': '#000000'},
#     {'color': '#4b4b4b',
#      'spectrum': '#3db657',
#      'hue': 'Grey',
#      'percent': 0.10165079365079364,
#      'css3': '#2f4f4f'},
#     {'color': '#646464',
#      'spectrum': '#7866ad',
#      'hue': 'Grey',
#      'percent': 0.08253968253968254,
#      'css3': '#696969'}],
#    'provenance': None,
#    'groupcount': 2,
#    'dated': '1940s-1950s',
#    'department': 'Busch-Reisinger Museum',
#    'dateend': 1959,
#    'people': [{'role': 'Artist',
#      'birthplace': 'New York, NY',
#      'gender': 'male',
#      'displaydate': '1871 - 1956',
#      'prefix': None,
#      'culture': 'American',
#      'displayname': 'Lyonel Feininger',
#      'alphasort': 'Feininger, Lyonel',
#      'name': 'Lyonel Feininger',
#      'personid': 20002,
#      'deathplace': 'New York, NY',
#      'displayorder': 1}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/1414',
#    'dateoffirstpageview': '2009-07-06',
#    'century': '20th century',
#    'objectnumber': 'BRLF.1003.6',
#    'labeltext': None,
#    'datebegin': 1940,
#    'culture': 'American',
#    'exhibitioncount': 0,
#    'imagepermissionlevel': 1,
#    'mediacount': 0,
#    'objectid': 1414,
#    'techniqueid': 220,
#    'dimensions': '3 x 3.5 cm (1 3/16 x 1 3/8 in.)',
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/1414',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#   {'copyright': '© Artists Rights Society (ARS), New York / VG Bild-Kunst, Bonn',
#    'contextualtextcount': 0,
#    'creditline': 'Harvard Art Museums/Busch-Reisinger Museum, Gift of T. Lux Feininger',
#    'accesslevel': 1,
#    'createdate': '2006-01-20T00:00:00-05:00',
#    'dateoflastpageview': '2023-04-05',
#    'classificationid': 17,
#    'division': 'Modern and Contemporary Art',
#    'markscount': 0,
#    'publicationcount': 0,
#    'totaluniquepageviews': 36,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'colorcount': 6,
#    'rank': 196456,
#    'id': 1415,
#    'state': None,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'period': None,
#    'images': [],
#    'worktypes': [{'worktypeid': '268', 'worktype': 'photograph'},
#     {'worktypeid': '341', 'worktype': 'slide'}],
#    'imagecount': 1,
#    'totalpageviews': 66,
#    'accessionyear': None,
#    'standardreferencenumber': None,
#    'signed': None,
#    'classification': 'Photographs',
#    'relatedcount': 1,
#    'verificationlevel': 2,
#    'primaryimageurl': None,
#    'titlescount': 1,
#    'peoplecount': 1,
#    'style': None,
#    'lastupdate': '2025-09-01T04:57:44-04:00',
#    'commentary': None,
#    'periodid': None,
#    'technique': 'Slide, 35 mm, black and white',
#    'edition': None,
#    'description': None,
#    'medium': None,
#    'lendingpermissionlevel': 0,
#    'title': '[Street scene in Berlin]',
#    'accessionmethod': 'Gift',
#    'colors': [{'color': '#000000',
#      'spectrum': '#1eb264',
#      'hue': 'Black',
#      'percent': 0.3748076923076923,
#      'css3': '#000000'},
#     {'color': '#191919',
#      'spectrum': '#1eb264',
#      'hue': 'Grey',
#      'percent': 0.1621153846153846,
#      'css3': '#000000'},
#     {'color': '#323232',
#      'spectrum': '#2eb45d',
#      'hue': 'Grey',
#      'percent': 0.11679487179487179,
#      'css3': '#2f4f4f'},
#     {'color': '#646464',
#      'spectrum': '#7866ad',
#      'hue': 'Grey',
#      'percent': 0.11647435897435897,
#      'css3': '#696969'},
#     {'color': '#4b4b4b',
#      'spectrum': '#3db657',
#      'hue': 'Grey',
#      'percent': 0.11576923076923076,
#      'css3': '#2f4f4f'},
#     {'color': '#7d7d7d',
#      'spectrum': '#8362aa',
#      'hue': 'Grey',
#      'percent': 0.11403846153846153,
#      'css3': '#808080'}],
#    'provenance': None,
#    'groupcount': 2,
#    'dated': '1940s-1950s',
#    'department': 'Busch-Reisinger Museum',
#    'dateend': 1959,
#    'people': [{'role': 'Artist',
#      'birthplace': 'New York, NY',
#      'gender': 'male',
#      'displaydate': '1871 - 1956',
#      'prefix': None,
#      'culture': 'American',
#      'displayname': 'Lyonel Feininger',
#      'alphasort': 'Feininger, Lyonel',
#      'name': 'Lyonel Feininger',
#      'personid': 20002,
#      'deathplace': 'New York, NY',
#      'displayorder': 1}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/1415',
#    'dateoffirstpageview': '2009-09-17',
#    'century': '20th century',
#    'objectnumber': 'BRLF.1003.8',
#    'labeltext': None,
#    'datebegin': 1940,
#    'culture': 'American',
#    'exhibitioncount': 0,
#    'imagepermissionlevel': 1,
#    'mediacount': 0,
#    'objectid': 1415,
#    'techniqueid': 220,
#    'dimensions': '3 x 3.5 cm (1 3/16 x 1 3/8 in.)',
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/1415',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#   {'copyright': '© Artists Rights Society (ARS), New York / VG Bild-Kunst, Bonn',
#    'contextualtextcount': 0,
#    'creditline': 'Harvard Art Museums/Busch-Reisinger Museum, Gift of T. Lux Feininger',
#    'accesslevel': 1,
#    'createdate': '2006-01-20T00:00:00-05:00',
#    'dateoflastpageview': '2025-06-08',
#    'classificationid': 17,
#    'division': 'Modern and Contemporary Art',
#    'markscount': 0,
#    'publicationcount': 0,
#    'totaluniquepageviews': 28,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'colorcount': 7,
#    'rank': 196457,
#    'id': 1416,
#    'state': None,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'period': None,
#    'images': [],
#    'worktypes': [{'worktypeid': '268', 'worktype': 'photograph'},
#     {'worktypeid': '341', 'worktype': 'slide'}],
#    'imagecount': 1,
#    'totalpageviews': 56,
#    'accessionyear': None,
#    'standardreferencenumber': None,
#    'signed': None,
#    'classification': 'Photographs',
#    'relatedcount': 1,
#    'verificationlevel': 2,
#    'primaryimageurl': None,
#    'titlescount': 1,
#    'peoplecount': 1,
#    'style': None,
#    'lastupdate': '2025-09-01T04:57:44-04:00',
#    'commentary': None,
#    'periodid': None,
#    'technique': 'Slide, 35 mm, black and white',
#    'edition': None,
#    'description': 'Corresponds to negative BRLF.106.2',
#    'medium': None,
#    'lendingpermissionlevel': 0,
#    'title': '[Shellhaus, Berlin]',
#    'accessionmethod': 'Gift',
#    'colors': [{'color': '#7d7d7d',
#      'spectrum': '#8362aa',
#      'hue': 'Grey',
#      'percent': 0.34425925925925926,
#      'css3': '#808080'},
#     {'color': '#4b4b4b',
#      'spectrum': '#3db657',
#      'hue': 'Grey',
#      'percent': 0.12524691358024692,
#      'css3': '#2f4f4f'},
#     {'color': '#969696',
#      'spectrum': '#8761aa',
#      'hue': 'Grey',
#      'percent': 0.11888888888888889,
#      'css3': '#a9a9a9'},
#     {'color': '#000000',
#      'spectrum': '#1eb264',
#      'hue': 'Black',
#      'percent': 0.11098765432098766,
#      'css3': '#000000'},
#     {'color': '#323232',
#      'spectrum': '#2eb45d',
#      'hue': 'Grey',
#      'percent': 0.1097530864197531,
#      'css3': '#2f4f4f'},
#     {'color': '#646464',
#      'spectrum': '#7866ad',
#      'hue': 'Grey',
#      'percent': 0.10030864197530864,
#      'css3': '#696969'},
#     {'color': '#191919',
#      'spectrum': '#1eb264',
#      'hue': 'Grey',
#      'percent': 0.09055555555555556,
#      'css3': '#000000'}],
#    'provenance': None,
#    'groupcount': 2,
#    'dated': '1940s-1950s',
#    'department': 'Busch-Reisinger Museum',
#    'dateend': 1959,
#    'people': [{'role': 'Artist',
#      'birthplace': 'New York, NY',
#      'gender': 'male',
#      'displaydate': '1871 - 1956',
#      'prefix': None,
#      'culture': 'American',
#      'displayname': 'Lyonel Feininger',
#      'alphasort': 'Feininger, Lyonel',
#      'name': 'Lyonel Feininger',
#      'personid': 20002,
#      'deathplace': 'New York, NY',
#      'displayorder': 1}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/1416',
#    'dateoffirstpageview': '2009-09-17',
#    'century': '20th century',
#    'objectnumber': 'BRLF.1003.9',
#    'labeltext': None,
#    'datebegin': 1940,
#    'culture': 'American',
#    'exhibitioncount': 0,
#    'imagepermissionlevel': 1,
#    'mediacount': 0,
#    'objectid': 1416,
#    'techniqueid': 220,
#    'dimensions': '3 x 3.5 cm (1 3/16 x 1 3/8 in.)',
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/1416',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#   {'copyright': '© Artists Rights Society (ARS), New York / VG Bild-Kunst, Bonn',
#    'contextualtextcount': 0,
#    'creditline': 'Harvard Art Museums/Busch-Reisinger Museum, Gift of T. Lux Feininger',
#    'accesslevel': 1,
#    'createdate': '2006-01-20T00:00:00-05:00',
#    'dateoflastpageview': '2025-03-19',
#    'classificationid': 17,
#    'division': 'Modern and Contemporary Art',
#    'markscount': 0,
#    'publicationcount': 0,
#    'totaluniquepageviews': 33,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'colorcount': 5,
#    'rank': 196464,
#    'id': 1417,
#    'state': None,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'period': None,
#    'images': [],
#    'worktypes': [{'worktypeid': '268', 'worktype': 'photograph'},
#     {'worktypeid': '341', 'worktype': 'slide'}],
#    'imagecount': 1,
#    'totalpageviews': 66,
#    'accessionyear': None,
#    'standardreferencenumber': None,
#    'signed': None,
#    'classification': 'Photographs',
#    'relatedcount': 1,
#    'verificationlevel': 2,
#    'primaryimageurl': None,
#    'titlescount': 1,
#    'peoplecount': 1,
#    'style': None,
#    'lastupdate': '2025-09-01T04:57:44-04:00',
#    'commentary': None,
#    'periodid': None,
#    'technique': 'Slide, 35 mm, black and white',
#    'edition': None,
#    'description': None,
#    'medium': None,
#    'lendingpermissionlevel': 0,
#    'title': '[Street scene, Berlin]',
#    'accessionmethod': 'Gift',
#    'colors': [{'color': '#000000',
#      'spectrum': '#1eb264',
#      'hue': 'Black',
#      'percent': 0.3142056074766355,
#      'css3': '#000000'},
#     {'color': '#323232',
#      'spectrum': '#2eb45d',
#      'hue': 'Grey',
#      'percent': 0.19657320872274142,
#      'css3': '#2f4f4f'},
#     {'color': '#4b4b4b',
#      'spectrum': '#3db657',
#      'hue': 'Grey',
#      'percent': 0.19109034267912772,
#      'css3': '#2f4f4f'},
#     {'color': '#646464',
#      'spectrum': '#7866ad',
#      'hue': 'Grey',
#      'percent': 0.1601246105919003,
#      'css3': '#696969'},
#     {'color': '#7d7d7d',
#      'spectrum': '#8362aa',
#      'hue': 'Grey',
#      'percent': 0.13800623052959501,
#      'css3': '#808080'}],
#    'provenance': None,
#    'groupcount': 2,
#    'dated': '1940s-1950s',
#    'department': 'Busch-Reisinger Museum',
#    'dateend': 1959,
#    'people': [{'role': 'Artist',
#      'birthplace': 'New York, NY',
#      'gender': 'male',
#      'displaydate': '1871 - 1956',
#      'prefix': None,
#      'culture': 'American',
#      'displayname': 'Lyonel Feininger',
#      'alphasort': 'Feininger, Lyonel',
#      'name': 'Lyonel Feininger',
#      'personid': 20002,
#      'deathplace': 'New York, NY',
#      'displayorder': 1}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/1417',
#    'dateoffirstpageview': '2009-07-27',
#    'century': '20th century',
#    'objectnumber': 'BRLF.1003.16',
#    'labeltext': None,
#    'datebegin': 1940,
#    'culture': 'American',
#    'exhibitioncount': 0,
#    'imagepermissionlevel': 1,
#    'mediacount': 0,
#    'objectid': 1417,
#    'techniqueid': 220,
#    'dimensions': '3 x 3.5 cm (1 3/16 x 1 3/8 in.)',
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/1417',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#   {'copyright': '© Artists Rights Society (ARS), New York / VG Bild-Kunst, Bonn',
#    'contextualtextcount': 0,
#    'creditline': 'Harvard Art Museums/Busch-Reisinger Museum, Gift of T. Lux Feininger',
#    'accesslevel': 1,
#    'createdate': '2006-01-20T00:00:00-05:00',
#    'dateoflastpageview': '2023-07-28',
#    'classificationid': 17,
#    'division': 'Modern and Contemporary Art',
#    'markscount': 0,
#    'publicationcount': 0,
#    'totaluniquepageviews': 63,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'colorcount': 4,
#    'rank': 196472,
#    'id': 1418,
#    'state': None,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'period': None,
#    'images': [],
#    'worktypes': [{'worktypeid': '341', 'worktype': 'slide'},
#     {'worktypeid': '268', 'worktype': 'photograph'}],
#    'imagecount': 1,
#    'totalpageviews': 106,
#    'accessionyear': None,
#    'standardreferencenumber': None,
#    'signed': None,
#    'classification': 'Photographs',
#    'relatedcount': 1,
#    'verificationlevel': 2,
#    'primaryimageurl': None,
#    'titlescount': 1,
#    'peoplecount': 1,
#    'style': None,
#    'lastupdate': '2025-09-01T04:57:44-04:00',
#    'commentary': None,
#    'periodid': None,
#    'technique': 'Slide, 35 mm, black and white',
#    'edition': None,
#    'description': 'Corresponds to negative BRLF.106.9',
#    'medium': None,
#    'lendingpermissionlevel': 0,
#    'title': '[Clothes blowing in the wind, Berlin]',
#    'accessionmethod': 'Gift',
#    'colors': [{'color': '#000000',
#      'spectrum': '#1eb264',
#      'hue': 'Black',
#      'percent': 0.32161993769470404,
#      'css3': '#000000'},
#     {'color': '#4b4b4b',
#      'spectrum': '#3db657',
#      'hue': 'Grey',
#      'percent': 0.2803738317757009,
#      'css3': '#2f4f4f'},
#     {'color': '#323232',
#      'spectrum': '#2eb45d',
#      'hue': 'Grey',
#      'percent': 0.25931464174454827,
#      'css3': '#2f4f4f'},
#     {'color': '#646464',
#      'spectrum': '#7866ad',
#      'hue': 'Grey',
#      'percent': 0.13869158878504673,
#      'css3': '#696969'}],
#    'provenance': None,
#    'groupcount': 2,
#    'dated': '1940s-1950s',
#    'department': 'Busch-Reisinger Museum',
#    'dateend': 1959,
#    'people': [{'role': 'Artist',
#      'birthplace': 'New York, NY',
#      'gender': 'male',
#      'displaydate': '1871 - 1956',
#      'prefix': None,
#      'culture': 'American',
#      'displayname': 'Lyonel Feininger',
#      'alphasort': 'Feininger, Lyonel',
#      'name': 'Lyonel Feininger',
#      'personid': 20002,
#      'deathplace': 'New York, NY',
#      'displayorder': 1}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/1418',
#    'dateoffirstpageview': '2009-09-17',
#    'century': '20th century',
#    'objectnumber': 'BRLF.1003.24',
#    'labeltext': None,
#    'datebegin': 1940,
#    'culture': 'American',
#    'exhibitioncount': 0,
#    'imagepermissionlevel': 1,
#    'mediacount': 0,
#    'objectid': 1418,
#    'techniqueid': 220,
#    'dimensions': '3 x 3.5 cm (1 3/16 x 1 3/8 in.)',
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/1418',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#   {'copyright': '© Artists Rights Society (ARS), New York / VG Bild-Kunst, Bonn',
#    'contextualtextcount': 0,
#    'creditline': 'Harvard Art Museums/Busch-Reisinger Museum, Gift of T. Lux Feininger',
#    'accesslevel': 1,
#    'createdate': '2006-01-20T00:00:00-05:00',
#    'dateoflastpageview': '2023-03-01',
#    'classificationid': 17,
#    'division': 'Modern and Contemporary Art',
#    'markscount': 0,
#    'publicationcount': 0,
#    'totaluniquepageviews': 43,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'colorcount': 6,
#    'rank': 196480,
#    'id': 1419,
#    'state': None,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'period': None,
#    'images': [],
#    'worktypes': [{'worktypeid': '341', 'worktype': 'slide'},
#     {'worktypeid': '268', 'worktype': 'photograph'}],
#    'imagecount': 1,
#    'totalpageviews': 87,
#    'accessionyear': None,
#    'standardreferencenumber': None,
#    'signed': None,
#    'classification': 'Photographs',
#    'relatedcount': 1,
#    'verificationlevel': 2,
#    'primaryimageurl': None,
#    'titlescount': 1,
#    'peoplecount': 1,
#    'style': None,
#    'lastupdate': '2025-09-01T04:57:44-04:00',
#    'commentary': None,
#    'periodid': None,
#    'technique': 'Slide, 35 mm, black and white',
#    'edition': None,
#    'description': None,
#    'medium': None,
#    'lendingpermissionlevel': 0,
#    'title': '[Building reflected in water, Deep, Baltic Coast]',
#    'accessionmethod': 'Gift',
#    'colors': [{'color': '#4b4b4b',
#      'spectrum': '#3db657',
#      'hue': 'Grey',
#      'percent': 0.40753894080996883,
#      'css3': '#2f4f4f'},
#     {'color': '#646464',
#      'spectrum': '#7866ad',
#      'hue': 'Grey',
#      'percent': 0.21626168224299067,
#      'css3': '#696969'},
#     {'color': '#000000',
#      'spectrum': '#1eb264',
#      'hue': 'Black',
#      'percent': 0.1412461059190031,
#      'css3': '#000000'},
#     {'color': '#c8c8c8',
#      'spectrum': '#8c5fa8',
#      'hue': 'Grey',
#      'percent': 0.08224299065420561,
#      'css3': '#c0c0c0'},
#     {'color': '#191919',
#      'spectrum': '#1eb264',
#      'hue': 'Grey',
#      'percent': 0.07981308411214953,
#      'css3': '#000000'},
#     {'color': '#7d7d7d',
#      'spectrum': '#8362aa',
#      'hue': 'Grey',
#      'percent': 0.07289719626168224,
#      'css3': '#808080'}],
#    'provenance': None,
#    'groupcount': 2,
#    'dated': '1940s-1950s',
#    'department': 'Busch-Reisinger Museum',
#    'dateend': 1959,
#    'people': [{'role': 'Artist',
#      'birthplace': 'New York, NY',
#      'gender': 'male',
#      'displaydate': '1871 - 1956',
#      'prefix': None,
#      'culture': 'American',
#      'displayname': 'Lyonel Feininger',
#      'alphasort': 'Feininger, Lyonel',
#      'name': 'Lyonel Feininger',
#      'personid': 20002,
#      'deathplace': 'New York, NY',
#      'displayorder': 1}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/1419',
#    'dateoffirstpageview': '2009-07-27',
#    'century': '20th century',
#    'objectnumber': 'BRLF.1003.32',
#    'labeltext': None,
#    'datebegin': 1940,
#    'culture': 'American',
#    'exhibitioncount': 0,
#    'imagepermissionlevel': 1,
#    'mediacount': 0,
#    'objectid': 1419,
#    'techniqueid': 220,
#    'dimensions': '3 x 3.5 cm (1 3/16 x 1 3/8 in.)',
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/1419',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#   {'copyright': None,
#    'contextualtextcount': 0,
#    'creditline': "Harvard Art Museums/Fogg Museum, Partial and Promised Gift of David M. Leventhal '71 in honor of Marjorie B. Cohn",
#    'accesslevel': 1,
#    'createdate': '2005-04-06T00:00:00-04:00',
#    'dateoflastpageview': '2025-08-24',
#    'classificationid': 21,
#    'division': 'European and American Art',
#    'markscount': 1,
#    'publicationcount': 15,
#    'totaluniquepageviews': 525,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'colorcount': 6,
#    'rank': 125859,
#    'id': 1423,
#    'state': None,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'period': None,
#    'images': [{'date': '2005-05-31',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 36477,
#      'idsid': 18204533,
#      'format': 'image/jpeg',
#      'description': 'Rendered in light graphite on pale gray paper, a young woman Is shown from the waist up. She is seated facing the viewer and is looking down and to the left with a calm expression, with her hands crossed in front of her. Her wavy hair is just visible tucked into her headdress, and she wear a dress with a high collar, puffy sleeves and gathered cuffs. Subtle shading carefully delineates the features of her face, while her hands are left incompletely rendered and the background is left blank.',
#      'technique': None,
#      'renditionnumber': '78315',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:78315_dynmc',
#      'alttext': 'Sketch of the head and torso of a woman in Renaissance dress',
#      'width': 802,
#      'publiccaption': None,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18204533',
#      'height': 1024}],
#    'worktypes': [{'worktypeid': '126', 'worktype': 'drawing'}],
#    'imagecount': 1,
#    'totalpageviews': 688,
#    'accessionyear': None,
#    'standardreferencenumber': None,
#    'signed': None,
#    'classification': 'Drawings',
#    'relatedcount': 0,
#    'verificationlevel': 4,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:78315_dynmc',
#    'titlescount': 1,
#    'peoplecount': 1,
#    'style': None,
#    'lastupdate': '2025-09-01T04:57:44-04:00',
#    'commentary': None,
#    'periodid': None,
#    'technique': None,
#    'edition': None,
#    'description': None,
#    'medium': 'Graphite on off-white wove paper',
#    'lendingpermissionlevel': 0,
#    'title': 'Portrait of a Woman, after a Drawing in the Uffizi then attributed to Leonardo da Vinci',
#    'accessionmethod': 'Not Recorded',
#    'colors': [{'color': '#c8c8c8',
#      'spectrum': '#8c5fa8',
#      'hue': 'Grey',
#      'percent': 0.5631339031339031,
#      'css3': '#c0c0c0'},
#     {'color': '#c8afaf',
#      'spectrum': '#b55592',
#      'hue': 'Red',
#      'percent': 0.37344729344729344,
#      'css3': '#c0c0c0'},
#     {'color': '#af9696',
#      'spectrum': '#ae5596',
#      'hue': 'Brown',
#      'percent': 0.04324786324786325,
#      'css3': '#bc8f8f'},
#     {'color': '#e1e1e1',
#      'spectrum': '#955ba5',
#      'hue': 'Grey',
#      'percent': 0.01566951566951567,
#      'css3': '#dcdcdc'},
#     {'color': '#7d7d7d',
#      'spectrum': '#8362aa',
#      'hue': 'Grey',
#      'percent': 0.003931623931623932,
#      'css3': '#808080'},
#     {'color': '#7d6464',
#      'spectrum': '#8e5ea7',
#      'hue': 'Brown',
#      'percent': 0.0005698005698005698,
#      'css3': '#696969'}],
#    'provenance': '[Fourth sale of the estate of Edgar Degas at the Galerie Georges Petit, Paris, July 2-4, 1919, lot 114a, sold]; [to Durand-Ruel, New York (1919-?), sold]; to Lillie P. Bliss, New York (?-1934), bequest; to Museum of Modern Art, New York (1934-1943), deaccessioned and sold; [through Jacques Seligmann & Co., New York, 1943]; to Robert L. Rosenwald, Jenkintown, PA (1943-?). Possibly Private Collection (?-1985), sold; [through Sotheby’s, New York, February 21, 1985, lot 154]; to David M. Leventhal, New York and London (1985-2005), partial and promised gift; to the Fogg Art Museum, 2005.\r\n\r\nNotes:\r\n1.  The drawing shared a frame with and was sold with three other drawings at the 1919 Degas estate sale (lots 114a-c). One of the other drawings (lot 114b) was bequeathed to the Fogg Art Museum in 1965 (1965.265).\r\n2. Lillie P. Bliss passed away in 1931 and her bequest to the Museum of Modern Art was finalized 3 years late, according to the terms of her will (which called for an adequate endowment fund to be secured in that interval).\r\n3.  In a sales room announcement for the February 21, 1985 sale, Sotheby’s publicized that Robert L. Rosenwald should additionally be listed as a previous owner of the drawing. Since Rosenwald was identified as a previous owner, it is likely that he was not the private collector offering the work at the sale, but that instead the drawing belonged to another private collector at the time. If this is the case, it is unclear when the drawing was acquired by the unknown private collector.  In his 1973 book “The History of Impressionism, “ John Rewald lists the drawing as still being in the collection of Robert L. Rosenwald.\r\n',
#    'groupcount': 0,
#    'dated': '1858 - 1859',
#    'department': 'Department of Drawings',
#    'dateend': 1859,
#    'people': [{'role': 'Artist',
#      'birthplace': 'Paris, France',
#      'gender': 'male',
#      'displaydate': '1834 - 1917',
#      'prefix': None,
#      'culture': 'French',
#      'displayname': 'Hilaire-Germain-Edgar Degas',
#      'alphasort': 'Degas, Hilaire-Germain-Edgar',
#      'name': 'Hilaire-Germain-Edgar Degas',
#      'personid': 35055,
#      'deathplace': 'Paris, France',
#      'displayorder': 1}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/1423',
#    'dateoffirstpageview': '2011-10-21',
#    'century': '19th century',
#    'objectnumber': '2005.79',
#    'labeltext': None,
#    'datebegin': 1858,
#    'culture': 'French',
#    'exhibitioncount': 4,
#    'imagepermissionlevel': 0,
#    'mediacount': 0,
#    'objectid': 1423,
#    'techniqueid': None,
#    'dimensions': '36.8 x 28 cm (14 1/2 x 11 in.)\r\nframe: 56.8 × 48.6 × 2.9 cm (22 3/8 × 19 1/8 × 1 1/8 in.)',
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/1423',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#   {'copyright': None,
#    'contextualtextcount': 0,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Gift of Robert Bradford Wheaton and Barbara Ketcham Wheaton',
#    'accesslevel': 1,
#    'createdate': '2005-05-17T00:00:00-04:00',
#    'dateoflastpageview': '2025-07-21',
#    'classificationid': 23,
#    'division': 'European and American Art',
#    'markscount': 5,
#    'publicationcount': 0,
#    'totaluniquepageviews': 30,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'colorcount': 7,
#    'rank': 245147,
#    'id': 1424,
#    'state': 'only state',
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'period': None,
#    'images': [{'date': '2008-05-13',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 306418,
#      'idsid': 20493753,
#      'format': 'image/jpeg',
#      'description': None,
#      'technique': None,
#      'renditionnumber': 'INV190170',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV190170_dynmc',
#      'alttext': None,
#      'width': 1024,
#      'publiccaption': None,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20493753',
#      'height': 788}],
#    'worktypes': [{'worktypeid': '288', 'worktype': 'print'}],
#    'imagecount': 1,
#    'totalpageviews': 46,
#    'accessionyear': 2005,
#    'standardreferencenumber': 'New Hollstein II.7.235',
#    'signed': None,
#    'classification': 'Prints',
#    'relatedcount': 1,
#    'verificationlevel': 3,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV190170_dynmc',
#    'titlescount': 2,
#    'peoplecount': 2,
#    'style': None,
#    'lastupdate': '2025-09-01T04:57:44-04:00',
#    'commentary': None,
#    'periodid': None,
#    'technique': 'Engraving',
#    'edition': None,
#    'description': 'illustrates April, corresponding zodiac sign (cancer) at top center',
#    'medium': None,
#    'lendingpermissionlevel': 0,
#    'title': 'The Parable of the Unjust Husbandmen',
#    'accessionmethod': 'Gift',
#    'colors': [{'color': '#c8c8af',
#      'spectrum': '#b55592',
#      'hue': 'Green',
#      'percent': 0.39866666666666667,
#      'css3': '#c0c0c0'},
#     {'color': '#c8af96',
#      'spectrum': '#e66c64',
#      'hue': 'Brown',
#      'percent': 0.25982608695652176,
#      'css3': '#d2b48c'},
#     {'color': '#644b32',
#      'spectrum': '#59ba4a',
#      'hue': 'Brown',
#      'percent': 0.08956521739130435,
#      'css3': '#556b2f'},
#     {'color': '#967d64',
#      'spectrum': '#b65590',
#      'hue': 'Brown',
#      'percent': 0.08104347826086956,
#      'css3': '#808080'},
#     {'color': '#7d644b',
#      'spectrum': '#b25593',
#      'hue': 'Yellow',
#      'percent': 0.07536231884057971,
#      'css3': '#696969'},
#     {'color': '#af967d',
#      'spectrum': '#c25687',
#      'hue': 'Brown',
#      'percent': 0.07281159420289855,
#      'css3': '#bc8f8f'},
#     {'color': '#e1e1c8',
#      'spectrum': '#e9715f',
#      'hue': 'Green',
#      'percent': 0.02272463768115942,
#      'css3': '#dcdcdc'}],
#    'provenance': 'Jan Reinier Voûte (Lugt 4450), Amsterdam. Robert Bradford Wheaton and Barbara Ketcham Wheaton, gift; to Harvard Art Museums, 2005',
#    'groupcount': 0,
#    'dated': '1585',
#    'department': 'Department of Prints',
#    'dateend': 1585,
#    'people': [{'role': 'Artist',
#      'birthplace': None,
#      'gender': 'male',
#      'displaydate': 'c. 1560 - 1618',
#      'prefix': None,
#      'culture': 'Flemish',
#      'displayname': 'Adriaen Collaert',
#      'alphasort': 'Collaert, Adriaen',
#      'name': 'Adriaen Collaert',
#      'personid': 33134,
#      'deathplace': None,
#      'displayorder': 1},
#     {'role': 'Artist after',
#      'birthplace': 'Mechelen, Belgium',
#      'gender': 'male',
#      'displaydate': '1534 - 1593',
#      'prefix': 'Designed by',
#      'culture': 'Netherlandish',
#      'displayname': 'Designed by Hans Bol',
#      'alphasort': 'Bol, Hans',
#      'name': 'Hans Bol',
#      'personid': 28680,
#      'deathplace': 'Amsterdam, Netherlands',
#      'displayorder': 2}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/1424',
#    'dateoffirstpageview': '2009-10-14',
#    'century': '16th century',
#    'objectnumber': 'M26620',
#    'labeltext': None,
#    'datebegin': 1585,
#    'culture': 'Flemish',
#    'exhibitioncount': 0,
#    'imagepermissionlevel': 0,
#    'mediacount': 0,
#    'objectid': 1424,
#    'techniqueid': 98,
#    'dimensions': 'plate: 15 x 20.5 cm (5 7/8 x 8 1/16 in.)\r\nsheet: 25.5 x 33.2 cm (10 1/16 x 13 1/16 in.)',
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/1424',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#   {'copyright': None,
#    'contextualtextcount': 0,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Gift of Robert Bradford Wheaton and Barbara Ketcham Wheaton',
#    'accesslevel': 1,
#    'createdate': '2005-05-17T00:00:00-04:00',
#    'dateoflastpageview': '2025-08-17',
#    'classificationid': 23,
#    'division': 'European and American Art',
#    'markscount': 5,
#    'publicationcount': 0,
#    'totaluniquepageviews': 37,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'colorcount': 8,
#    'rank': 245149,
#    'id': 1425,
#    'state': 'only state',
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'period': None,
#    'images': [{'date': '2008-05-13',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 306408,
#      'idsid': 20493743,
#      'format': 'image/jpeg',
#      'description': None,
#      'technique': None,
#      'renditionnumber': 'INV190160',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV190160_dynmc',
#      'alttext': None,
#      'width': 1024,
#      'publiccaption': None,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20493743',
#      'height': 793}],
#    'worktypes': [{'worktypeid': '288', 'worktype': 'print'}],
#    'imagecount': 1,
#    'totalpageviews': 59,
#    'accessionyear': 2005,
#    'standardreferencenumber': 'New Hollstein II.7.237',
#    'signed': None,
#    'classification': 'Prints',
#    'relatedcount': 1,
#    'verificationlevel': 3,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV190160_dynmc',
#    'titlescount': 2,
#    'peoplecount': 2,
#    'style': None,
#    'lastupdate': '2025-09-01T04:57:44-04:00',
#    'commentary': None,
#    'periodid': None,
#    'technique': 'Engraving',
#    'edition': None,
#    'description': 'illustrates December, corresponding zodiac sign (capricorn) at the center top',
#    'medium': None,
#    'lendingpermissionlevel': 0,
#    'title': 'The Virgin and Joseph at the Inn',
#    'accessionmethod': 'Gift',
#    'colors': [{'color': '#c8af96',
#      'spectrum': '#e66c64',
#      'hue': 'Brown',
#      'percent': 0.36557471264367813,
#      'css3': '#d2b48c'},
#     {'color': '#e1c8af',
#      'spectrum': '#e9715f',
#      'hue': 'Orange',
#      'percent': 0.2878735632183908,
#      'css3': '#f5deb3'},
#     {'color': '#644b32',
#      'spectrum': '#59ba4a',
#      'hue': 'Brown',
#      'percent': 0.08264367816091954,
#      'css3': '#556b2f'},
#     {'color': '#af967d',
#      'spectrum': '#c25687',
#      'hue': 'Brown',
#      'percent': 0.07867816091954023,
#      'css3': '#bc8f8f'},
#     {'color': '#7d644b',
#      'spectrum': '#b25593',
#      'hue': 'Yellow',
#      'percent': 0.07396551724137931,
#      'css3': '#696969'},
#     {'color': '#967d64',
#      'spectrum': '#b65590',
#      'hue': 'Brown',
#      'percent': 0.05994252873563218,
#      'css3': '#808080'},
#     {'color': '#4b3219',
#      'spectrum': '#4ab851',
#      'hue': 'Brown',
#      'percent': 0.03310344827586207,
#      'css3': '#556b2f'},
#     {'color': '#e1e1c8',
#      'spectrum': '#e9715f',
#      'hue': 'Green',
#      'percent': 0.018218390804597702,
#      'css3': '#dcdcdc'}],
#    'provenance': 'Jan Reinier Voûte (Lugt 4450), Amsterdam. Robert Bradford Wheaton and Barbara Ketcham Wheaton, gift; to Harvard Art Museums, 2005',
#    'groupcount': 0,
#    'dated': '1585',
#    'department': 'Department of Prints',
#    'dateend': 1585,
#    'people': [{'role': 'Artist',
#      'birthplace': None,
#      'gender': 'male',
#      'displaydate': 'c. 1560 - 1618',
#      'prefix': None,
#      'culture': 'Flemish',
#      'displayname': 'Adriaen Collaert',
#      'alphasort': 'Collaert, Adriaen',
#      'name': 'Adriaen Collaert',
#      'personid': 33134,
#      'deathplace': None,
#      'displayorder': 1},
#     {'role': 'Artist after',
#      'birthplace': 'Mechelen, Belgium',
#      'gender': 'male',
#      'displaydate': '1534 - 1593',
#      'prefix': 'Designed by',
#      'culture': 'Netherlandish',
#      'displayname': 'Designed by Hans Bol',
#      'alphasort': 'Bol, Hans',
#      'name': 'Hans Bol',
#      'personid': 28680,
#      'deathplace': 'Amsterdam, Netherlands',
#      'displayorder': 2}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/1425',
#    'dateoffirstpageview': '2009-08-31',
#    'century': '16th century',
#    'objectnumber': 'M26622',
#    'labeltext': None,
#    'datebegin': 1585,
#    'culture': 'Flemish',
#    'exhibitioncount': 0,
#    'imagepermissionlevel': 0,
#    'mediacount': 0,
#    'objectid': 1425,
#    'techniqueid': 98,
#    'dimensions': 'plate: 15 x 20.5 cm (5 7/8 x 8 1/16 in.)\r\nsheet: 25.5 x 33.2 cm (10 1/16 x 13 1/16 in.)',
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/1425',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#   {'copyright': None,
#    'contextualtextcount': 0,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Gift of Robert Bradford Wheaton and Barbara Ketcham Wheaton',
#    'accesslevel': 1,
#    'createdate': '2005-05-17T00:00:00-04:00',
#    'dateoflastpageview': '2025-08-17',
#    'classificationid': 23,
#    'division': 'European and American Art',
#    'markscount': 0,
#    'publicationcount': 0,
#    'totaluniquepageviews': 43,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'colorcount': 0,
#    'rank': 245381,
#    'id': 1426,
#    'state': None,
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'period': None,
#    'worktypes': [{'worktypeid': '289', 'worktype': 'print series'}],
#    'imagecount': 0,
#    'totalpageviews': 74,
#    'accessionyear': 2005,
#    'standardreferencenumber': 'H. 619-631',
#    'signed': None,
#    'classification': 'Prints',
#    'relatedcount': 13,
#    'verificationlevel': 3,
#    'titlescount': 2,
#    'peoplecount': 2,
#    'style': None,
#    'lastupdate': '2025-09-01T04:57:44-04:00',
#    'commentary': None,
#    'periodid': None,
#    'technique': 'Engraving',
#    'edition': None,
#    'description': None,
#    'medium': None,
#    'lendingpermissionlevel': 0,
#    'title': 'Twelve Roman Emperors (XII Caesarum)',
#    'accessionmethod': 'Gift',
#    'provenance': None,
#    'groupcount': 0,
#    'dated': '1608',
#    'department': 'Department of Prints',
#    'dateend': 1608,
#    'people': [{'role': 'Artist',
#      'birthplace': None,
#      'gender': 'male',
#      'displaydate': '1581 - 1662',
#      'prefix': None,
#      'culture': 'German',
#      'displayname': 'Wolfgang Kilian',
#      'alphasort': 'Kilian, Wolfgang',
#      'name': 'Wolfgang Kilian',
#      'personid': 30194,
#      'deathplace': None,
#      'displayorder': 1},
#     {'role': 'Publisher',
#      'birthplace': None,
#      'gender': 'unknown',
#      'displaydate': '1583 - 1620',
#      'prefix': None,
#      'culture': 'Flemish',
#      'displayname': 'Justus Sadeler',
#      'alphasort': 'Sadeler, Justus',
#      'name': 'Justus Sadeler',
#      'personid': 26135,
#      'deathplace': None,
#      'displayorder': 2}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/1426',
#    'dateoffirstpageview': '2009-05-24',
#    'century': '16th-17th century',
#    'objectnumber': 'M26647.-M26659',
#    'labeltext': None,
#    'datebegin': 1608,
#    'culture': 'German',
#    'exhibitioncount': 0,
#    'imagepermissionlevel': 0,
#    'mediacount': 0,
#    'objectid': 1426,
#    'techniqueid': 98,
#    'dimensions': None},
#   {'copyright': '© Nolde Stiftung Seebüll, Germany',
#    'contextualtextcount': 0,
#    'creditline': 'Harvard Art Museums/Busch-Reisinger Museum, Gift of Barbara Butts and Michael Parke-Taylor in honor of Konrad Oberhuber',
#    'accesslevel': 1,
#    'createdate': '2005-11-17T00:00:00-05:00',
#    'dateoflastpageview': '2025-08-17',
#    'classificationid': 23,
#    'division': 'Modern and Contemporary Art',
#    'markscount': 7,
#    'publicationcount': 0,
#    'totaluniquepageviews': 56,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'colorcount': 10,
#    'rank': 126331,
#    'id': 1427,
#    'state': None,
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'period': None,
#    'images': [],
#    'worktypes': [{'worktypeid': '282', 'worktype': 'postcard'},
#     {'worktypeid': '288', 'worktype': 'print'}],
#    'imagecount': 1,
#    'totalpageviews': 85,
#    'accessionyear': 2005,
#    'standardreferencenumber': 'Reuther 27',
#    'signed': None,
#    'classification': 'Prints',
#    'relatedcount': 0,
#    'verificationlevel': 3,
#    'primaryimageurl': None,
#    'titlescount': 3,
#    'peoplecount': 1,
#    'style': None,
#    'lastupdate': '2025-09-01T04:57:44-04:00',
#    'commentary': None,
#    'periodid': None,
#    'technique': 'Photomechanical print',
#    'edition': None,
#    'description': 'The postcard bears the printed signature "E.Hansen"\r\nPrinted at l.l.: F. Killinger, Zürich. Nr. 27.\r\n',
#    'medium': 'Photomechanical print on white wove paper',
#    'lendingpermissionlevel': 0,
#    'title': 'The Guards of the Rose Garden',
#    'accessionmethod': 'Gift',
#    'colors': [{'color': '#e1e1e1',
#      'spectrum': '#955ba5',
#      'hue': 'Grey',
#      'percent': 0.20527777777777778,
#      'css3': '#dcdcdc'},
#     {'color': '#e1c8af',
#      'spectrum': '#e9715f',
#      'hue': 'Orange',
#      'percent': 0.1711111111111111,
#      'css3': '#f5deb3'},
#     {'color': '#c8af96',
#      'spectrum': '#e66c64',
#      'hue': 'Brown',
#      'percent': 0.14291666666666666,
#      'css3': '#d2b48c'},
#     {'color': '#96afaf',
#      'spectrum': '#7b65ad',
#      'hue': 'Blue',
#      'percent': 0.11805555555555555,
#      'css3': '#a9a9a9'},
#     {'color': '#af967d',
#      'spectrum': '#c25687',
#      'hue': 'Brown',
#      'percent': 0.09152777777777778,
#      'css3': '#bc8f8f'},
#     {'color': '#af644b',
# ...
#    'lendingpermissionlevel': 0,
#    'title': 'Cloud Scissors',
#    'accessionmethod': 'Partial Gift/Partial Purchase',
#    'colors': [{'color': '#e1e1e1',
#      'spectrum': '#955ba5',
#      'hue': 'Grey',
#      'percent': 0.6403883495145631,
#      'css3': '#dcdcdc'},
#     {'color': '#afafaf',
#      'spectrum': '#8c5fa8',
#      'hue': 'Grey',
#      'percent': 0.20757281553398058,
#      'css3': '#a9a9a9'},
#     {'color': '#c8c8c8',
#      'spectrum': '#8c5fa8',
#      'hue': 'Grey',
#      'percent': 0.14711974110032364,
#      'css3': '#c0c0c0'},
#     {'color': '#969696',
#      'spectrum': '#8761aa',
#      'hue': 'Grey',
#      'percent': 0.004919093851132686,
#      'css3': '#a9a9a9'}],
#    'provenance': 'Barbara Moore, Bound/Unbound, New York, New York, partial gift partial purchase; to Harvard University Art Museums, June 28, 2005.',
#    'groupcount': 0,
#    'dated': 'late 1960s',
#    'department': 'Department of Prints',
#    'dateend': 1960,
#    'people': [{'role': 'Artist',
#      'birthplace': 'New York, NY',
#      'gender': 'male',
#      'displaydate': '1926 - 2008',
#      'prefix': None,
#      'culture': 'American',
#      'displayname': 'George Brecht',
#      'alphasort': 'Brecht, George',
#      'name': 'George Brecht',
#      'personid': 29606,
#      'deathplace': 'Cologne, Germany',
#      'displayorder': 1},
#     {'role': 'Publisher',
#      'birthplace': None,
#      'gender': 'unidentified',
#      'displaydate': None,
#      'prefix': 'Published by',
#      'culture': 'American',
#      'displayname': 'Published by Fluxus',
#      'alphasort': 'Fluxus',
#      'name': 'Fluxus',
#      'personid': 26489,
#      'deathplace': None,
#      'displayorder': 2}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/4653',
#    'dateoffirstpageview': '2009-08-01',
#    'century': '20th century',
#    'objectnumber': 'M26448.3',
#    'labeltext': None,
#    'datebegin': 1960,
#    'culture': 'American',
#    'exhibitioncount': 1,
#    'imagepermissionlevel': 1,
#    'mediacount': 0,
#    'objectid': 4653,
#    'techniqueid': 466,
#    'dimensions': '9.3 x 11.7 cm (3 11/16 x 4 5/8 in.)',
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/4653',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#   {'copyright': None,
#    'contextualtextcount': 0,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Gift of Patricia Cornwell',
#    'accesslevel': 1,
#    'createdate': '2005-12-20T00:00:00-05:00',
#    'dateoflastpageview': '2025-08-04',
#    'classificationid': 21,
#    'division': 'European and American Art',
#    'markscount': 7,
#    'publicationcount': 2,
#    'totaluniquepageviews': 205,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'colorcount': 4,
#    'rank': 126426,
#    'id': 4654,
#    'state': None,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'period': None,
#    'images': [{'date': '2006-05-10',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 175283,
#      'idsid': 18822154,
#      'format': 'image/jpeg',
#      'description': None,
#      'technique': None,
#      'renditionnumber': 'INV044587',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV044587_dynmc',
#      'alttext': None,
#      'width': 919,
#      'publiccaption': None,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18822154',
#      'height': 1024},
#     {'date': '2006-11-03',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 204230,
#      'idsid': 20236613,
#      'format': 'image/jpeg',
#      'description': 'Small, square sheet of beige paper with images on each side. On one side are two parallel lines running the length of the page. Between the two lines is a wide graphite zig-zag scribble. On the other side, a version of Whistler’s “butterfly” signature occupies the whole page. An S-shaped blue watercolor line makes up the butterfly’s body. Its wings are two crescent shapes, one painted light gray and the other unpainted, with fan-shaped peach areas at the outer edges.',
#      'technique': None,
#      'renditionnumber': 'INV115610',
#      'displayorder': 2,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV115610_dynmc',
#      'alttext': 'Page with scribble on one side and abstract butterfly drawing on other',
#      'width': 919,
#      'publiccaption': None,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20236613',
#      'height': 1024}],
#    'worktypes': [{'worktypeid': '126', 'worktype': 'drawing'}],
#    'imagecount': 2,
#    'totalpageviews': 255,
#    'accessionyear': 2005,
#    'standardreferencenumber': None,
#    'signed': None,
#    'classification': 'Drawings',
#    'relatedcount': 0,
#    'verificationlevel': 4,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV044587_dynmc',
#    'titlescount': 1,
#    'peoplecount': 1,
#    'style': None,
#    'lastupdate': '2025-09-01T04:57:45-04:00',
#    'commentary': None,
#    'periodid': None,
#    'technique': None,
#    'edition': None,
#    'description': None,
#    'medium': 'Graphite and watercolor on beige laid paper',
#    'lendingpermissionlevel': 0,
#    'title': "Butterfly for a Valance at Dowdeswell's Gallery",
#    'accessionmethod': 'Gift',
#    'colors': [{'color': '#e1c8c8',
#      'spectrum': '#c15689',
#      'hue': 'Orange',
#      'percent': 0.7901492537313433,
#      'css3': '#d8bfd8'},
#     {'color': '#c8c8af',
#      'spectrum': '#b55592',
#      'hue': 'Green',
#      'percent': 0.20606965174129352,
#      'css3': '#c0c0c0'},
#     {'color': '#c8967d',
#      'spectrum': '#e66c64',
#      'hue': 'Grey',
#      'percent': 0.0024875621890547263,
#      'css3': '#bc8f8f'},
#     {'color': '#96967d',
#      'spectrum': '#8e5ea7',
#      'hue': 'Green',
#      'percent': 0.0012935323383084577,
#      'css3': '#808080'}],
#    'provenance': "Alexander J. Taylor.\r\nErnst Arnold, Dresden, 1911.\r\nKonrad Zimmermann, Berlin.\r\nPrivate Collector, Britain. According to MacDonald, offered for sale to Lowell Art Association (April 11 and June 24, 1953)\r\nNordness, London. 1962-1966\r\nFine Art Society PLC, London, purchased at Sotheby's, London, 1974.\r\nSotheby's, London, sold to Fine Arts Society, 1974. Sale, London, June 19, 1974, lot 50.\r\nPatricia Cornwell, Belmont, MA, gift to Harvard University Art Museums, 2005.\r\n",
#    'groupcount': 0,
#    'dated': 'c. 1884',
#    'department': 'Department of Drawings',
#    'dateend': 1889,
#    'people': [{'role': 'Artist',
#      'birthplace': 'Lowell, MA',
#      'gender': 'male',
#      'displaydate': '1834 - 1903',
#      'prefix': None,
#      'culture': 'American',
#      'displayname': 'James Abbott McNeill Whistler',
#      'alphasort': 'Whistler, James Abbott McNeill',
#      'name': 'James Abbott McNeill Whistler',
#      'personid': 29383,
#      'deathplace': 'London, England',
#      'displayorder': 1}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/4654',
#    'dateoffirstpageview': '2009-09-10',
#    'century': '19th century',
#    'objectnumber': '2005.260',
#    'labeltext': None,
#    'datebegin': 1879,
#    'culture': 'American',
#    'exhibitioncount': 2,
#    'imagepermissionlevel': 0,
#    'mediacount': 0,
#    'objectid': 4654,
#    'techniqueid': None,
#    'dimensions': '7.3 x 7.6 cm (2 7/8 x 3 in.)',
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/4654',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#   {'copyright': None,
#    'contextualtextcount': 0,
#    'creditline': 'Harvard University Portrait Collection, Bequest from Elfrieda K. Bowditch to the Department of Cellular and Molecular Physiology, Harvard Medical School',
#    'accesslevel': 1,
#    'createdate': '2006-01-24T00:00:00-05:00',
#    'dateoflastpageview': '2025-05-26',
#    'classificationid': 26,
#    'division': 'European and American Art',
#    'markscount': 1,
#    'publicationcount': 0,
#    'totaluniquepageviews': 72,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'colorcount': 0,
#    'rank': 214888,
#    'id': 4655,
#    'state': None,
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'period': None,
#    'worktypes': [{'worktypeid': '250', 'worktype': 'painting'}],
#    'imagecount': 0,
#    'totalpageviews': 118,
#    'accessionyear': None,
#    'standardreferencenumber': None,
#    'signed': 'l.r.: Lud. Nieper pinx/ 1871',
#    'classification': 'Paintings',
#    'relatedcount': 1,
#    'verificationlevel': 3,
#    'titlescount': 1,
#    'peoplecount': 2,
#    'style': None,
#    'lastupdate': '2025-09-01T04:57:45-04:00',
#    'commentary': None,
#    'periodid': None,
#    'technique': None,
#    'edition': None,
#    'description': None,
#    'medium': 'Oil on canvas',
#    'lendingpermissionlevel': 0,
#    'title': 'Selma Knauth Bowditch (1853-1918)',
#    'accessionmethod': 'Not Recorded',
#    'provenance': None,
#    'groupcount': 0,
#    'dated': '1871',
#    'department': 'Harvard University Portrait Collection',
#    'dateend': 1871,
#    'people': [{'role': 'Artist',
#      'birthplace': None,
#      'gender': 'unknown',
#      'displaydate': '1826 - 1906',
#      'prefix': None,
#      'culture': 'German',
#      'displayname': 'Ludwig Nieper',
#      'alphasort': 'Nieper, Ludwig',
#      'name': 'Ludwig Nieper',
#      'personid': 26389,
#      'deathplace': None,
#      'displayorder': 1},
#     {'role': 'Sitter',
#      'birthplace': None,
#      'gender': 'unknown',
#      'displaydate': '1853 - 1918',
#      'prefix': None,
#      'culture': None,
#      'displayname': 'Selma Knauth Bowditch',
#      'alphasort': 'Bowditch, Selma Knauth',
#      'name': 'Selma Knauth Bowditch',
#      'personid': 9990,
#      'deathplace': None,
#      'displayorder': 2}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/4655',
#    'dateoffirstpageview': '2009-10-11',
#    'century': '19th century',
#    'objectnumber': 'HNA137',
#    'labeltext': None,
#    'datebegin': 1871,
#    'culture': 'German',
#    'exhibitioncount': 0,
#    'imagepermissionlevel': 0,
#    'mediacount': 0,
#    'objectid': 4655,
#    'techniqueid': None,
#    'dimensions': 'oval: 88.9 x 76.2 cm (35 x 30 in.)'},
#   {'copyright': None,
#    'contextualtextcount': 0,
#    'creditline': 'Harvard University Portrait Collection, Harvard Medical School',
#    'accesslevel': 1,
#    'createdate': '2006-01-24T00:00:00-05:00',
#    'dateoflastpageview': '2025-03-20',
#    'classificationid': 26,
#    'division': 'Modern and Contemporary Art',
#    'markscount': 0,
#    'publicationcount': 0,
#    'totaluniquepageviews': 33,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'colorcount': 0,
#    'rank': 214892,
#    'id': 4656,
#    'state': None,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'period': None,
#    'worktypes': [{'worktypeid': '250', 'worktype': 'painting'}],
#    'imagecount': 0,
#    'totalpageviews': 55,
#    'accessionyear': None,
#    'standardreferencenumber': None,
#    'signed': 'l.r.: Leslie P. Thompson  1935',
#    'classification': 'Paintings',
#    'relatedcount': 0,
#    'verificationlevel': 2,
#    'titlescount': 1,
#    'peoplecount': 2,
#    'style': None,
#    'lastupdate': '2025-09-01T04:57:45-04:00',
#    'commentary': None,
#    'periodid': None,
#    'technique': None,
#    'edition': None,
#    'description': None,
#    'medium': 'Oil on canvas',
#    'lendingpermissionlevel': 0,
#    'title': 'William Townsend Porter (1862-1949)',
#    'accessionmethod': 'Not Recorded',
#    'provenance': None,
#    'groupcount': 0,
#    'dated': '1935',
#    'department': 'Harvard University Portrait Collection',
#    'dateend': 1935,
#    'people': [{'role': 'Artist',
#      'birthplace': 'Medford, MA',
#      'gender': 'unknown',
#      'displaydate': '1880 - 1963',
#      'prefix': None,
#      'culture': 'American',
#      'displayname': 'Leslie P. Thompson',
#      'alphasort': 'Thompson, Leslie P.',
#      'name': 'Leslie P. Thompson',
#      'personid': 29992,
#      'deathplace': 'Boston, MA',
#      'displayorder': 1},
#     {'role': 'Sitter',
#      'birthplace': None,
#      'gender': 'unknown',
#      'displaydate': '1862-1949',
#      'prefix': None,
#      'culture': None,
#      'displayname': 'Willim Townsend Porter',
#      'alphasort': 'Porter, Willim Townsend',
#      'name': 'Willim Townsend Porter',
#      'personid': 9991,
#      'deathplace': None,
#      'displayorder': 2}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/4656',
#    'dateoffirstpageview': '2009-06-25',
#    'century': '20th century',
#    'objectnumber': 'HNA140',
#    'labeltext': None,
#    'datebegin': 1935,
#    'culture': 'American',
#    'exhibitioncount': 0,
#    'imagepermissionlevel': 0,
#    'mediacount': 0,
#    'objectid': 4656,
#    'techniqueid': None,
#    'dimensions': '76.2 x 63.5 cm (30 x 25 in.)\r\nFramed: 90.2 x 77.5 cm (35 1/2 x 30 1/2 in.)'},
#   {'copyright': '© Artists Rights Society (ARS), New York / VG Bild-Kunst, Bonn',
#    'contextualtextcount': 0,
#    'creditline': 'Harvard Art Museums/Busch-Reisinger Museum, Gift of T. Lux Feininger',
#    'accesslevel': 1,
#    'createdate': '2006-01-20T00:00:00-05:00',
#    'dateoflastpageview': '2025-03-09',
#    'classificationid': 17,
#    'division': 'Modern and Contemporary Art',
#    'markscount': 0,
#    'publicationcount': 0,
#    'totaluniquepageviews': 1,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'colorcount': 5,
#    'rank': 196440,
#    'id': 4667,
#    'state': None,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'period': None,
#    'images': [],
#    'worktypes': [{'worktypeid': '341', 'worktype': 'slide'},
#     {'worktypeid': '268', 'worktype': 'photograph'}],
#    'imagecount': 1,
#    'totalpageviews': 1,
#    'accessionyear': None,
#    'standardreferencenumber': None,
#    'signed': None,
#    'classification': 'Photographs',
#    'relatedcount': 1,
#    'verificationlevel': 2,
#    'primaryimageurl': None,
#    'titlescount': 1,
#    'peoplecount': 1,
#    'style': None,
#    'lastupdate': '2025-09-01T04:57:45-04:00',
#    'commentary': None,
#    'periodid': None,
#    'technique': 'Slide, 35 mm, black and white',
#    'edition': None,
#    'description': None,
#    'medium': None,
#    'lendingpermissionlevel': 0,
#    'title': '[Street scene, Germany]',
#    'accessionmethod': 'Gift',
#    'colors': [{'color': '#000000',
#      'spectrum': '#1eb264',
#      'hue': 'Black',
#      'percent': 0.26193146417445484,
#      'css3': '#000000'},
#     {'color': '#323232',
#      'spectrum': '#2eb45d',
#      'hue': 'Grey',
#      'percent': 0.2560747663551402,
#      'css3': '#2f4f4f'},
#     {'color': '#4b4b4b',
#      'spectrum': '#3db657',
#      'hue': 'Grey',
#      'percent': 0.18149532710280375,
#      'css3': '#2f4f4f'},
#     {'color': '#191919',
#      'spectrum': '#1eb264',
#      'hue': 'Grey',
#      'percent': 0.159190031152648,
#      'css3': '#000000'},
#     {'color': '#646464',
#      'spectrum': '#7866ad',
#      'hue': 'Grey',
#      'percent': 0.14130841121495327,
#      'css3': '#696969'}],
#    'provenance': None,
#    'groupcount': 2,
#    'dated': '1940s-1950s',
#    'department': 'Busch-Reisinger Museum',
#    'dateend': 1959,
#    'people': [{'role': 'Artist',
#      'birthplace': 'New York, NY',
#      'gender': 'male',
#      'displaydate': '1871 - 1956',
#      'prefix': None,
#      'culture': 'American',
#      'displayname': 'Lyonel Feininger',
#      'alphasort': 'Feininger, Lyonel',
#      'name': 'Lyonel Feininger',
#      'personid': 20002,
#      'deathplace': 'New York, NY',
#      'displayorder': 1}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/4667',
#    'dateoffirstpageview': '2025-03-09',
#    'century': '20th century',
#    'objectnumber': 'BRLF.1002.208',
#    'labeltext': None,
#    'datebegin': 1940,
#    'culture': 'American',
#    'exhibitioncount': 0,
#    'imagepermissionlevel': 1,
#    'mediacount': 0,
#    'objectid': 4667,
#    'techniqueid': 220,
#    'dimensions': '3 x 3.5 cm (1 3/16 x 1 3/8 in.)',
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/4667',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]}]}

# %%
metadata = []
for i in data_objects['records'] :
  metadata.append(dict(
        id = i.get('id'),
        title = i.get('title'),
        culture = i.get('culture'),
        period = i.get('period'),
        century = i.get('century'),
        medium = i.get('medium'),
        dimensions = i.get('dimensions'),
        department = i.get('department'),
        classification = i.get('classification'),
        accessionyear = i.get('accessionyear'),
        accessionmethod = i.get('accessionmethod')

  ))

# %%
pd.DataFrame(metadata)
# Out:
#       id                                            title   culture period  \
# 0   1412             [Buildings, Germany (Siemensstadt?)]  American   None
# 1   1413                     [Buildings, Stockholm, 1936]  American   None
# 2   1414                           [Street scene, Berlin]  American   None
# 3   1415                         [Street scene in Berlin]  American   None
# 4   1416                              [Shellhaus, Berlin]  American   None
# ..   ...                                              ...       ...    ...
# 95  4653                                   Cloud Scissors  American   None
# 96  4654  Butterfly for a Valance at Dowdeswell's Gallery  American   None
# 97  4655                Selma Knauth Bowditch (1853-1918)    German   None
# 98  4656              William Townsend Porter (1862-1949)  American   None
# 99  4667                          [Street scene, Germany]  American   None
#
#          century                                       medium  \
# 0   20th century                                         None
# 1   20th century                                         None
# 2   20th century                                         None
# 3   20th century                                         None
# 4   20th century                                         None
# ..           ...                                          ...
# 95  20th century                   Offset lithograph on paper
# 96  19th century  Graphite and watercolor on beige laid paper
# 97  19th century                                Oil on canvas
# 98  20th century                                Oil on canvas
# 99  20th century                                         None
#
#                                            dimensions  \
# 0                     3 x 3.5 cm (1 3/16 x 1 3/8 in.)
# 1                     3 x 3.5 cm (1 3/16 x 1 3/8 in.)
# 2                     3 x 3.5 cm (1 3/16 x 1 3/8 in.)
# 3                     3 x 3.5 cm (1 3/16 x 1 3/8 in.)
# 4                     3 x 3.5 cm (1 3/16 x 1 3/8 in.)
# ..                                                ...
# 95                9.3 x 11.7 cm (3 11/16 x 4 5/8 in.)
# 96                       7.3 x 7.6 cm (2 7/8 x 3 in.)
# 97                 oval: 88.9 x 76.2 cm (35 x 30 in.)
# 98  76.2 x 63.5 cm (30 x 25 in.)\r\nFramed: 90.2 x...
# 99                    3 x 3.5 cm (1 3/16 x 1 3/8 in.)
#
#                                 department classification  accessionyear  \
# 0                   Busch-Reisinger Museum    Photographs            NaN
# 1                   Busch-Reisinger Museum    Photographs            NaN
# 2                   Busch-Reisinger Museum    Photographs            NaN
# 3                   Busch-Reisinger Museum    Photographs            NaN
# 4                   Busch-Reisinger Museum    Photographs            NaN
# ..                                     ...            ...            ...
# 95                    Department of Prints         Prints         2005.0
# 96                  Department of Drawings       Drawings         2005.0
# 97  Harvard University Portrait Collection      Paintings            NaN
# 98  Harvard University Portrait Collection      Paintings            NaN
# 99                  Busch-Reisinger Museum    Photographs            NaN
#
#                   accessionmethod
# 0                            Gift
# 1                            Gift
# 2                            Gift
# 3                            Gift
# 4                            Gift
# ..                            ...
# 95  Partial Gift/Partial Purchase
# 96                           Gift
# 97                   Not Recorded
# 98                   Not Recorded
# 99                           Gift
#
# [100 rows x 11 columns]

# %%
df_metadata =pd.DataFrame(metadata)

# %%
mediadata = []
for i in data_objects['records']:
  mediadata.append(dict(
        objectid = i.get('objectid'),
        imagecount = i.get('imagecount'),
        mediacount = i.get('mediacount'),
        colorcount = i.get('colorcount'),
        rank = i.get('rank'),
        datebegin = i.get('datebegin'),
        dateend = i.get('dateend')

  ))

# %%
df_metadata =pd.DataFrame(metadata)

# %%
df_mediadata=pd.DataFrame(mediadata)

# %%
colordata = []
for i in data_objects['records']:
  colordata.append(dict(
        objectid = i.get('objectid'),
        spectrum = i.get('spectrum'),
        hue = i.get('hue'),
        percent= i.get('percent'),
        css3 = i.get('css3')
))

# %%
df_colors= pd.DataFrame(colordata)

# %%
df_mediadata
# Out:
#     objectid  imagecount  mediacount  colorcount    rank  datebegin  dateend
# 0       1412           1           0           3  196446       1940     1959
# 1       1413           1           0           8  196447       1940     1959
# 2       1414           1           0           7  196454       1940     1959
# 3       1415           1           0           6  196456       1940     1959
# 4       1416           1           0           7  196457       1940     1959
# ..       ...         ...         ...         ...     ...        ...      ...
# 95      4653           1           0           4  244870       1960     1960
# 96      4654           2           0           4  126426       1879     1889
# 97      4655           0           0           0  214888       1871     1871
# 98      4656           0           0           0  214892       1935     1935
# 99      4667           1           0           5  196440       1940     1959
#
# [100 rows x 7 columns]

# %%
import sqlite3
import pandas as pd


conn = sqlite3.connect(r"C:\Users\Windows\Downloads\HarvardMuseum.db")
cursor = conn.cursor()
cursor.execute("""
CREATE TABLE IF NOT EXISTS artifact_colors (
    objectid INTEGER,
    spectrum TEXT,
    hue TEXT,
    percent REAL,
    css3 TEXT
);
""")
conn.commit()
cursor.execute("""
CREATE TABLE IF NOT EXISTS artifact_metadata (
    id INTEGER PRIMARY KEY,
    title TEXT,
    culture TEXT,
    period TEXT,
    century TEXT,
    medium TEXT,
    dimensions TEXT,
    department TEXT,
    classification TEXT,
    accessionyear INTEGER,
    accessionmethod TEXT
);
""")
conn.commit()
cursor.execute("""
CREATE TABLE IF NOT EXISTS artifact_media (
    objectid INTEGER,
    imagecount INTEGER,
    mediacount INTEGER,
    colorcount INTEGER,
    rank INTEGER,
    datebegin INTEGER,
    dateend INTEGER,
    FOREIGN KEY (objectid) REFERENCES artifact_metadata(id)
);
""")
conn.commit()

cursor.execute("""
DELETE FROM artifact_colors;
""")
conn.commit()
cursor.execute("""
DELETE FROM artifact_metadata;
""")
conn.commit()
cursor.execute("""
DELETE FROM artifact_media;
""")
conn.commit()

df_colors.to_sql('artifact_colors', conn, if_exists='append', index=False)
df_metadata.to_sql('artifact_metadata', conn, if_exists='append', index=False)
df_mediadata.to_sql('artifact_media', conn, if_exists='append', index=False)
conn.close()

# %%
import streamlit as st
import sqlite3
import pandas as pd

DB_PATH = r"C:\Users\Windows\Downloads\HarvardMuseum.db"

# Utility function to run SQL queries
def run_query(query: str) -> pd.DataFrame:
    try:
        with sqlite3.connect(DB_PATH) as conn:
            return pd.read_sql_query(query, conn)
    except sqlite3.Error as e:
        st.error(f"Database error: {e}")
        return pd.DataFrame()
    except Exception as e:
        st.error(f"Unexpected error: {e}")
        return pd.DataFrame()

st.title("🏛️ Harvard Museum Artifact Explorer")

# Create tabs for different sections
tab1, tab2, tab3, tab4 = st.tabs([
    "🗃️ Artifact Metadata", 
    "🖼️ Artifact Media", 
    "🎨 Artifact Colors", 
    "🔗 Join-Based Queries"
])

with tab1:
    st.header("🗃️ Artifact Metadata Table")
    
    # Query 1: 11th century Byzantine artifacts
    st.subheader("1. 11th Century Byzantine Artifacts")
    query1 = """
    SELECT * FROM artifact_metadata
    WHERE century = '11th Century' AND culture = 'Byzantine';
    """
    df1 = run_query(query1)
    if not df1.empty:
        st.dataframe(df1)
        st.write(f"**Total artifacts:** {len(df1)}")
    else:
        st.info("No 11th century Byzantine artifacts found")

    # Query 2: Unique cultures
    st.subheader("2. Unique Cultures")
    query2 = """
    SELECT DISTINCT culture FROM artifact_metadata
    WHERE culture IS NOT NULL AND TRIM(culture) != ''
    ORDER BY culture;
    """
    df2 = run_query(query2)
    if not df2.empty:
        st.dataframe(df2)
        st.write(f"**Total unique cultures:** {len(df2)}")
    else:
        st.info("No culture data available")

    # Query 3: Archaic Period artifacts
    st.subheader("3. Archaic Period Artifacts")
    query3 = """
    SELECT * FROM artifact_metadata
    WHERE period = 'Archaic';
    """
    df3 = run_query(query3)
    if not df3.empty:
        st.dataframe(df3)
        st.write(f"**Total Archaic period artifacts:** {len(df3)}")
    else:
        st.info("No Archaic period artifacts found")

    # Query 4: Titles by accession year
    st.subheader("4. Artifact Titles by Accession Year")
    query4 = """
    SELECT title, accessionyear FROM artifact_metadata
    WHERE accessionyear IS NOT NULL
    ORDER BY accessionyear DESC;
    """
    df4 = run_query(query4)
    if not df4.empty:
        st.dataframe(df4)
    else:
        st.info("No accession year data available")

    # Query 5: Artifacts per department
    st.subheader("5. Artifacts per Department")
    query5 = """
    SELECT department, COUNT(*) AS artifact_count
    FROM artifact_metadata
    WHERE department IS NOT NULL AND TRIM(department) != ''
    GROUP BY department
    ORDER BY artifact_count DESC;
    """
    df5 = run_query(query5)
    if not df5.empty:
        st.dataframe(df5)
        st.bar_chart(df5.set_index('department'))
    else:
        st.info("No department data available")

with tab2:
    st.header("🖼️ Artifact Media Table")
    
    # Query 1: Artifacts with more than 1 image
    st.subheader("1. Artifacts with Multiple Images")
    query1_media = """
    SELECT artifact_id, COUNT(*) as image_count
    FROM artifact_media
    GROUP BY artifact_id
    HAVING COUNT(*) > 1
    ORDER BY image_count DESC;
    """
    df1_media = run_query(query1_media)
    if not df1_media.empty:
        st.dataframe(df1_media)
        st.write(f"**Artifacts with multiple images:** {len(df1_media)}")
    else:
        st.info("No artifacts with multiple images found")

    # Query 2: Average rank
    st.subheader("2. Average Rank of Artifacts")
    query2_media = """
    SELECT AVG(rank) as average_rank FROM artifact_media;
    """
    df2_media = run_query(query2_media)
    if not df2_media.empty:
        avg_rank = df2_media.iloc[0]['average_rank']
        st.metric("Average Rank", f"{avg_rank:.2f}")
    else:
        st.info("No rank data available")

    # Query 3: Colorcount > Mediascount
    st.subheader("3. Artifacts with Colorcount > Mediascount")
    query3_media = """
    SELECT artifact_id, colorcount, mediacount
    FROM artifact_media
    WHERE colorcount > mediacount;
    """
    df3_media = run_query(query3_media)
    if not df3_media.empty:
        st.dataframe(df3_media)
        st.write(f"**Artifacts with colorcount > mediacount:** {len(df3_media)}")
    else:
        st.info("No artifacts with colorcount greater than mediacount")

    # Query 4: Artifacts from 1500-1600
    st.subheader("4. Artifacts Created Between 1500-1600")
    query4_media = """
    SELECT am.*, meta.title, meta.culture
    FROM artifact_media am
    JOIN artifact_metadata meta ON am.artifact_id = meta.id
    WHERE am.creationdate BETWEEN 1500 AND 1600;
    """
    df4_media = run_query(query4_media)
    if not df4_media.empty:
        st.dataframe(df4_media)
        st.write(f"**Artifacts from 1500-1600:** {len(df4_media)}")
    else:
        st.info("No artifacts found from 1500-1600")

    # Query 5: Artifacts with no media
    st.subheader("5. Artifacts with No Media Files")
    query5_media = """
    SELECT meta.id, meta.title
    FROM artifact_metadata meta
    LEFT JOIN artifact_media media ON meta.id = media.artifact_id
    WHERE media.artifact_id IS NULL;
    """
    df5_media = run_query(query5_media)
    if not df5_media.empty:
        st.dataframe(df5_media)
        st.write(f"**Artifacts with no media:** {len(df5_media)}")
    else:
        st.info("All artifacts have media files")

with tab3:
    st.header("🎨 Artifact Colors Table")
    
    # Query 1: Distinct hues
    st.subheader("1. Distinct Hues")
    query1_colors = """
    SELECT DISTINCT hue FROM artifact_colors
    WHERE hue IS NOT NULL AND TRIM(hue) != ''
    ORDER BY hue;
    """
    df1_colors = run_query(query1_colors)
    if not df1_colors.empty:
        st.dataframe(df1_colors)
        st.write(f"**Total distinct hues:** {len(df1_colors)}")
    else:
        st.info("No hue data available")

    # Query 2: Top 5 colors by frequency
    st.subheader("2. Top 5 Most Used Colors")
    query2_colors = """
    SELECT hue, COUNT(*) as frequency
    FROM artifact_colors
    WHERE hue IS NOT NULL AND TRIM(hue) != ''
    GROUP BY hue
    ORDER BY frequency DESC
    LIMIT 5;
    """
    df2_colors = run_query(query2_colors)
    if not df2_colors.empty:
        st.dataframe(df2_colors)
        st.bar_chart(df2_colors.set_index('hue'))
    else:
        st.info("No color frequency data available")

    # Query 3: Average coverage by hue
    st.subheader("3. Average Coverage by Hue")
    query3_colors = """
    SELECT hue, AVG(coverage) as avg_coverage
    FROM artifact_colors
    WHERE hue IS NOT NULL AND TRIM(hue) != ''
    GROUP BY hue
    ORDER BY avg_coverage DESC;
    """
    df3_colors = run_query(query3_colors)
    if not df3_colors.empty:
        st.dataframe(df3_colors)
    else:
        st.info("No coverage data available")

    # Query 4: Colors for a specific artifact
    st.subheader("4. Colors for a Specific Artifact")
    artifact_id = st.text_input("Enter Artifact ID:", value="12345")
    if artifact_id:
        query4_colors = f"""
        SELECT * FROM artifact_colors
        WHERE artifact_id = '{artifact_id}'
        ORDER BY coverage DESC;
        """
        df4_colors = run_query(query4_colors)
        if not df4_colors.empty:
            st.dataframe(df4_colors)
            st.write(f"**Colors found:** {len(df4_colors)}")
        else:
            st.info(f"No colors found for artifact ID: {artifact_id}")

    # Query 5: Total color entries
    st.subheader("5. Total Color Entries")
    query5_colors = "SELECT COUNT(*) as total_entries FROM artifact_colors;"
    df5_colors = run_query(query5_colors)
    if not df5_colors.empty:
        total = df5_colors.iloc[0]['total_entries']
        st.metric("Total Color Entries", total)
    else:
        st.info("No color entries found")

with tab4:
    st.header("🔗 Join-Based Queries")
    
    # Query 1: Byzantine artifacts with hues
    st.subheader("1. Byzantine Artifacts with Hues")
    query1_join = """
    SELECT meta.title, colors.hue, colors.coverage
    FROM artifact_metadata meta
    JOIN artifact_colors colors ON meta.id = colors.artifact_id
    WHERE meta.culture = 'Byzantine'
    ORDER BY meta.title, colors.coverage DESC;
    """
    df1_join = run_query(query1_join)
    if not df1_join.empty:
        st.dataframe(df1_join)
        st.write(f"**Byzantine artifacts with color data:** {len(df1_join)}")
    else:
        st.info("No Byzantine artifacts with color data found")

    # Query 2: All artifacts with hues
    st.subheader("2. All Artifacts with Associated Hues")
    query2_join = """
    SELECT meta.title, colors.hue, colors.coverage
    FROM artifact_metadata meta
    JOIN artifact_colors colors ON meta.id = colors.artifact_id
    ORDER BY meta.title, colors.coverage DESC
    LIMIT 1000;
    """
    df2_join = run_query(query2_join)
    if not df2_join.empty:
        st.dataframe(df2_join)
        st.write("Showing first 1000 results")
    else:
        st.info("No artifact-color associations found")

    # Query 3: Artifacts with period not null
    st.subheader("3. Artifacts with Period Data and Media Ranks")
    query3_join = """
    SELECT meta.title, meta.culture, media.rank
    FROM artifact_metadata meta
    JOIN artifact_media media ON meta.id = media.artifact_id
    WHERE meta.period IS NOT NULL AND TRIM(meta.period) != ''
    ORDER BY media.rank DESC
    LIMIT 500;
    """
    df3_join = run_query(query3_join)
    if not df3_join.empty:
        st.dataframe(df3_join)
        st.write("Showing top 500 results by rank")
    else:
        st.info("No artifacts with period data found")

    # Query 4: Top 10 artifacts with Grey hue
    st.subheader("4. Top 10 Artifacts with Grey Color")
    query4_join = """
    SELECT meta.title, meta.culture, media.rank, colors.coverage
    FROM artifact_metadata meta
    JOIN artifact_media media ON meta.id = media.artifact_id
    JOIN artifact_colors colors ON meta.id = colors.artifact_id
    WHERE colors.hue = 'Grey'
    ORDER BY media.rank DESC
    LIMIT 10;
    """
    df4_join = run_query(query4_join)
    if not df4_join.empty:
        st.dataframe(df4_join)
    else:
        st.info("No artifacts with Grey color found")

    # Query 5: Artifacts per classification with avg media count
    st.subheader("5. Artifacts per Classification with Average Media Count")
    query5_join = """
    SELECT 
        meta.classification,
        COUNT(*) as artifact_count,
        AVG(media.mediacount) as avg_media_count
    FROM artifact_metadata meta
    JOIN artifact_media media ON meta.id = media.artifact_id
    WHERE meta.classification IS NOT NULL AND TRIM(meta.classification) != ''
    GROUP BY meta.classification
    ORDER BY artifact_count DESC;
    """
    df5_join = run_query(query5_join)
    if not df5_join.empty:
        st.dataframe(df5_join)
        col1, col2 = st.columns(2)
        with col1:
            st.bar_chart(df5_join.set_index('classification')['artifact_count'])
        with col2:
            st.bar_chart(df5_join.set_index('classification')['avg_media_count'])
    else:
        st.info("No classification data available")

# Add debug section to check database connection
with st.sidebar:
    st.header("🔧 Database Info")
    if st.button("Check Database Connection"):
        try:
            with sqlite3.connect(DB_PATH) as conn:
                tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", conn)
                st.write("Available tables:")
                st.dataframe(tables)
                
                # Show sample data from each table
                for table in tables['name']:
                    sample = pd.read_sql_query(f"SELECT * FROM {table} LIMIT 1;", conn)
                    st.write(f"Sample from {table}:")
                    st.dataframe(sample)
                    
        except Exception as e:
            st.error(f"Database connection failed: {e}")
# Out:
# 2025-09-02 16:17:40.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.261 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.261 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.373 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.386 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.393 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.405 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.445 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.453 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.457 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.466 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.477 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.492 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.524 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.530 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.540 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.608 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.613 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.656 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.978 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.984 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.984 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.990 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:40.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.004 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.032 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.041 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.066 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.074 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.079 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.086 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.184 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.235 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.319 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.326 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.329 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.344 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.350 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.362 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.390 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.424 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.429 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.443 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.461 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.470 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.492 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.506 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.510 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.518 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.521 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.535 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.570 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.578 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.585 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.606 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.614 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.665 Session state does not function when running a script without `streamlit run`
# 2025-09-02 16:17:41.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.692 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.698 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.740 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.745 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.760 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.774 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.797 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.807 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.813 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.847 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.863 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.874 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.878 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.882 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.891 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.891 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.950 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.958 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.970 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.974 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.980 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:41.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.000 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.010 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.015 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.029 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.038 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.043 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.058 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.072 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.086 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.092 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.094 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.095 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.095 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-02 16:17:42.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
